# %% [markdown]
# ## Capstone project for Basic Data Science
# In this project, I explored the Data preprocessing techniques learned.I used pandas, plots and the different data preprocessing techniques to explore and analyse the data.
# This project is on Exploratory Data Analysis

# %% [markdown]
# # Bello Ayodeji 11/5/2024

# %% [markdown]
# Step1: Import the necessary libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
#List the set of available datasets in seaborn
print(len(sns.get_dataset_names()))
print(sns.get_dataset_names())
# Out:
# 88
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# Dataset 1: exercise

# %%
#1.Write the syntax for choosing the specific dataset
#syntax for reading "peguins" file from the seaborn dataset
df = sns.load_dataset("exercise")
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
#2.Display the top 5 records of penguin dataset
df.head(5)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
#3.Display the dimensionality of the dataset
df.shape
# Out:
# (90, 6)

# %%
#4.Display the datatypes of the attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  90 non-null     int64
#  1   id          90 non-null     int64
#  2   diet        90 non-null     category
#  3   pulse       90 non-null     int64
#  4   time        90 non-null     category
#  5   kind        90 non-null     category
# dtypes: category(3), int64(3)
# memory usage: 2.9 KB

# %%
#5.Describe the dataset extensively
df.describe()
# Out:
#        Unnamed: 0         id       pulse
# count   90.000000  90.000000   90.000000
# mean    44.500000  15.500000   99.700000
# std     26.124701   8.703932   14.858471
# min      0.000000   1.000000   80.000000
# 25%     22.250000   8.000000   90.250000
# 50%     44.500000  15.500000   96.000000
# 75%     66.750000  23.000000  103.000000
# max     89.000000  30.000000  150.000000

# %%
#6.Display the number of null values in the dataset and the total count of it
df.isna().sum()
# Out:
# Unnamed: 0    0
# id            0
# diet          0
# pulse         0
# time          0
# kind          0
# dtype: int64

# %%
#7.Identify the columns having null values and remove them
penguins_cleaned = df.dropna()
penguins_cleaned
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
# 8.check the size of dataset after cleaning and compare with the size before cleaning
print("dataset before cleaning", df.shape)
print("dataset after cleaning", penguins_cleaned.shape)
# Out:
# dataset before cleaning (90, 6)
# dataset after cleaning (90, 6)

# %%
#9.Find out the count of male and female penguins
sns.countplot(data=penguins_cleaned, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#10.Find out the count of species 
count_of_species = sns.countplot(data=penguins_cleaned, x='species')

# %%
#11. Use a countplot graph to display the number of male and female penguins
#Give the plot a title "Count of male and female penguins"
#Give a xlabel and ylabel
CountOfMaleAndFemale = sns.countplot(data=df, x='sex')
plt.title('Count of Male and Female Penguins')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
#12. For all the penguins display the bill_length_mm and bill_depth_mm using pairplot
sns.pairplot(data=df,x_vars='bill_length_mm',y_vars='bill_depth_mm')
# Out:
# C:\Users\PC\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#13.Create a visualization to display the flipper_length_mm and body_mass_g for the penguin dataset.
sns.pairplot(data=df,x_vars='flipper_length_mm',y_vars='body_mass_g')
# Out:
# C:\Users\PC\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#sns.histplot(data=penguins_cleaned, x="flipper_length_mm", bins=10)

# %%
#14. Create a histogram with the flipper_length_mm and bins = 10
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
ax1.hist(df['flipper_length_mm'], bins=10, histtype='bar')
fig.suptitle('Histogram of flipper_length_mm',fontsize=16)
fig.set_size_inches(8,6)
plt.show()

# %%
#15. Create a joint point with body_length_mm, body_depth_mm for penguins_cleaned dataset
sns.jointplot(data=df, x="bill_length_mm", y = "bill_depth_mm")

# %%
#16. Use a pairwise plot to display all the numerical values of the dataset penguins_cleaned
sns.pairplot(data = df)
# Out:
# C:\Users\PC\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#17.Check if there exists any outliers based on the boxplot based on numerical values  of penguins_cleaned dataset
sns.boxplot(y='bill_depth_mm', data=df)
# Out:
# <Axes: ylabel='bill_depth_mm'>

# %%
sns.boxplot(y='flipper_length_mm', data=df)
# Out:
# <Axes: ylabel='flipper_length_mm'>

# %%
sns.boxplot(y='bill_length_mm', data=df)
# Out:
# <Axes: ylabel='bill_length_mm'>

# %%
#18. Create a violin plot to display the body_mass_g of different species based on sex

sns.violinplot(data = df, x = "species", y = "body_mass_g", hue = "sex")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>
